# %%
import urllib2
from bs4 import BeautifulSoup
articleURL = "https://www.washingtonpost.com/news/the-switch/wp/2016/10/18/the-pentagons-massive-new-telescope-is-designed-to-track-space-junk-and-watch-out-for-killer-asteroids/?utm_term=.f41bf58f307d"
page = urllib2.urlopen(articleURL).read().decode('utf8', 'ignore')
soup = BeautifulSoup(page,"lxml")
soup
# Out:
# <!DOCTYPE html>\n<html class="blog layout_article rendering-context-www" itemscope="" itemtype="http://schema.org/NewsArticle" lang="en"> <head> <script id="_$cookiemonster">(function(b,m){function d(b,d){this.wl={map:f.map.concat(b||[]),reg:f.reg.concat(d||[])}}var f={reg:[],map:[]};d.prototype.ommNom=function(){return this.nom(!0,void 0)};d.prototype.allows=function(b){return!(-1<this.nom(!1,[b]).indexOf(b))};d.prototype.nom=function(d,f){for(var c=[],l=b.location.hostname.split("").reverse().join("").slice(0,18),g=f||b.cookie.split(";"),a,h,e=0;e<g.length,a=g[e];e++)a=a.trim().split("\\x3d")[0].toLowerCase(),-1<this.wl.map.indexOf(a)||c.push(a);for(var k=0;k<this.wl.reg.length,\nh=this.wl.reg[k];k++)for(e=h.lastIndex=0;e<g.length,a=g[e];e++)a=a.trim().split("\\x3d")[0].toLowerCase(),h.test(a)?-1<c.indexOf(a)&&c.splice(c.indexOf(a),1):0>c.indexOf(a)&&0>this.wl.map.indexOf(a)&&c.push(a);d&&("moc.tsopnotgnihsaw"==l&&(this.wl.reg.length||this.wl.map.length)?setTimeout(function(a){return function(){for(var a=0;a<c.length;a++)b.cookie=c[a]+"\\x3d; expires\\x3dThu, 01 Jan 1970 00:00:01 GMT; path\\x3d/; domain\\x3dwww.washingtonpost.com",b.cookie=c[a]+"\\x3d; expires\\x3dThu, 01 Jan 1970 00:00:01 GMT; path\\x3d/; domain\\x3d.washingtonpost.com",\nb.cookie=c[a]+"\\x3d; expires\\x3dThu, 01 Jan 1970 00:00:01 GMT; path\\x3d/; domain\\x3d"}}(this),0):console.error("[cookie-monster] Cowardly refusing to delete cookies on "+b.location.hostname,c));return c};return b.__CookieMonster__=d})(document);</script> <script>console.time("header-start");</script> <script>var TWP_Debug=window.TWP_Debug||{};TWP_Debug.initialTime=new Date;window.pageBuilder=window.pageBuilder||{};window.pageBuilder.loadAsyncFeatures=function(){__e=window.__e||[];__e.push(["lazy-scroll",function(){var b=window.document.getElementsByClassName("pb-async");[].slice.call(b).map(function(a){return a.id}).forEach(function(a){window.pageBuilder.loadAsyncFeature(a)})}])};window.pageBuilder.featureLoaded=function(){$(window.document).trigger("dom-manipulation-complete")};</script> <meta content="1501850471" name="object-hash"/> <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/> <meta charset="unicode-escape"/> <meta content="width=device-width, initial-scale=1.0, user-scalable=yes, minimum-scale=0.5, maximum-scale=2.0" id="viewport" name="viewport"/> <meta content="unsafe-url" name="referrer"/> <meta content="darpa, space surveillance telescope, space debris, brian weeden, space fence, air force" name="keywords"/> <meta content="darpa, space surveillance telescope, space debris, brian weeden, space fence, air force" name="news_keywords"/> <meta name="twitter:site" value="@WashingtonPost"/> <meta content="summary_large_image" name="twitter:card"/> <meta content="article" property="og:type"/> <meta content="Washington Post" property="og:site_name"/> <meta content="True" itemprop="mainEntityOfPage"/> <meta content="https://www.facebook.com/washingtonpost" property="article:publisher"/> <meta content="1513210492" property="fb:admins"/> <meta content="41245586762" property="fb:app_id"/> <meta content="1244584375" property="fb:admins"/> <meta content="4403963" property="fb:admins"/> <meta content="2724956" property="fb:admins"/> <meta content="500835072" property="fb:admins"/> <link href="/pb/resources/json/desktop-notifications-manifest.json" rel="manifest"/> <title>The Pentagon\u2019s massive new telescope is designed to track space junk and watch out for killer asteroids - The Washington Post</title> <link href="https://www.washingtonpost.com/news/the-switch/wp/2016/10/18/the-pentagons-massive-new-telescope-is-designed-to-track-space-junk-and-watch-out-for-killer-asteroids/" itemprop="url" rel="canonical"/> <meta content="https://www.washingtonpost.com/news/the-switch/wp/2016/10/18/the-pentagons-massive-new-telescope-is-designed-to-track-space-junk-and-watch-out-for-killer-asteroids/" property="og:url"/> <meta content="https://img.washingtonpost.com/rf/image_1484w/201 ...

# %%
soup.find('article')
# Out:
# <article itemprop="articleBody"> <div class="inline-content inline-video"> <div class="posttv-video-embed powa" data-ad-bar="1" data-aspect-ratio="0.5625" data-blurb="1" data-live="0" data-object-id="580640a4e4b0d16481f68b07" data-org="wapo" data-playthrough="1" data-uuid="24fd7912-9548-11e6-9cae-2a3574e296a6" data-youtube-id="aGH_nLCOWOw"> <script defer="" src="https://d1pz6dax0t5mop.cloudfront.net/prod/PoWaLoaderWapo.js"></script> </div> <div class="inline-video-caption"> <span class="pb-caption">The Space Surveillance Telescope offers improvements in determining the orbits of newly discovered objects and provides rapid observations of events that may only occur over a relatively short period of time, like a supernova. (DARPAtv)</span> </div> </div> <p>There are a lot of rocks flying around through space. Lots of debris, too. Old satellites, spent rocket boosters, even for a short while a spatula that got loose during a space shuttle mission in 2006. All of it swirling around in orbit, creating a bit of a traffic jam.</p> <p>For years, the Pentagon has been worried about the collisions that might be caused by an\xa0estimated 500,000 pieces of debris, taking out enormously valuable satellites and, in turn, creating even more debris. On Tuesday, the Defense Department\xa0took another significant step toward monitoring all of the cosmic junk swirling around in space, by delivering\xa0a gigantic new telescope capable of seeing small objects from very far away.</p> <p>Developed by the Defense Advanced Research Project Agency, the Space Surveillance Telescope was formally transferred to the Air Force during a ceremony at White Sands Missile Base in New Mexico Tuesday.</p> <p>The telescope is designed to monitor objects as small as softballs, in Geosynchonous orbit (GEO)\u2014some of the most important real estate in space. At about 22,000 miles away, its orbit mirrors that of the Earth, so that satellites parked there remain in a fixed point over the globe. That allows satellite television or communications providers to serve particular areas\u2014say, North America or Asia\u2014uninterrupted.</p> <p>But not only is the orbit far away\u2014it\u2019s incredibly vast. \u201cA volume of tens of thousands of oceans,\u201d said Lindsay Millard, DARPA\u2019s program manager in a podcast posted on the agency\u2019s website. But the telescope's ability to see \u201csomething very far away over a very wide area is really what it\u2019s best at.\u201d</p> <p>DARPA says the advanced technology in the massive, 90-ton telescope would\xa0allow officials to go from \u201cseeing only a few large objects at a time through the equivalent of a drinking straw to a windshield view with 10,000 objects at a time.\u201d\xa0It is also being used by NASA to monitor asteroids and other near-Earth objects that could collide with the planet, officials said.</p> <p>Over the next two years, the telescope is going to be moved and reconstructed in Australia, a vantage point that would allow it to survey an under served area of space.</p> <p>The telescope is \u201ca big improvement over the legacy ground-based optical telescopes that are used by the U.S. Air Force, because it can search large areas of sky and also track very faint (small) objects in and around GEO,\u201d Brian Weeden, a Technical Advisor at the Secure World Foundation, wrote in an email. \u201cThat's a critical capability for the U.S. military, as they have a lot of very important satellites in GEO, and are increasingly worried about threats to those satellites.\u201d</p> <p>The telescope would\xa0join another new space debris tracking technology known as the Space Fence, which is now being built by Bethesda-based Lockheed Martin. The radar system is going to be located on Kwajalein Atoll in the Marshall Islands and would use radar to help the Air Force track 10 times amount of debris than it currently monitors.</p> <p>With many valuable assets in space\u2014satellites used for intelligence, commu ...

# %%
soup.find('article').text
# Out:
# u"      The Space Surveillance Telescope offers improvements in determining the orbits of newly discovered objects and provides rapid observations of events that may only occur over a relatively short period of time, like a supernova. (DARPAtv)   There are a lot of rocks flying around through space. Lots of debris, too. Old satellites, spent rocket boosters, even for a short while a spatula that got loose during a space shuttle mission in 2006. All of it swirling around in orbit, creating a bit of a traffic jam. For years, the Pentagon has been worried about the collisions that might be caused by an\xa0estimated 500,000 pieces of debris, taking out enormously valuable satellites and, in turn, creating even more debris. On Tuesday, the Defense Department\xa0took another significant step toward monitoring all of the cosmic junk swirling around in space, by delivering\xa0a gigantic new telescope capable of seeing small objects from very far away. Developed by the Defense Advanced Research Project Agency, the Space Surveillance Telescope was formally transferred to the Air Force during a ceremony at White Sands Missile Base in New Mexico Tuesday. The telescope is designed to monitor objects as small as softballs, in Geosynchonous orbit (GEO)\u2014some of the most important real estate in space. At about 22,000 miles away, its orbit mirrors that of the Earth, so that satellites parked there remain in a fixed point over the globe. That allows satellite television or communications providers to serve particular areas\u2014say, North America or Asia\u2014uninterrupted. But not only is the orbit far away\u2014it\u2019s incredibly vast. \u201cA volume of tens of thousands of oceans,\u201d said Lindsay Millard, DARPA\u2019s program manager in a podcast posted on the agency\u2019s website. But the telescope's ability to see \u201csomething very far away over a very wide area is really what it\u2019s best at.\u201d DARPA says the advanced technology in the massive, 90-ton telescope would\xa0allow officials to go from \u201cseeing only a few large objects at a time through the equivalent of a drinking straw to a windshield view with 10,000 objects at a time.\u201d\xa0It is also being used by NASA to monitor asteroids and other near-Earth objects that could collide with the planet, officials said. Over the next two years, the telescope is going to be moved and reconstructed in Australia, a vantage point that would allow it to survey an under served area of space. The telescope is \u201ca big improvement over the legacy ground-based optical telescopes that are used by the U.S. Air Force, because it can search large areas of sky and also track very faint (small) objects in and around GEO,\u201d Brian Weeden, a Technical Advisor at the Secure World Foundation, wrote in an email. \u201cThat's a critical capability for the U.S. military, as they have a lot of very important satellites in GEO, and are increasingly worried about threats to those satellites.\u201d The telescope would\xa0join another new space debris tracking technology known as the Space Fence, which is now being built by Bethesda-based Lockheed Martin. The radar system is going to be located on Kwajalein Atoll in the Marshall Islands and would use radar to help the Air Force track 10 times amount of debris than it currently monitors. With many valuable assets in space\u2014satellites used for intelligence, communications and guiding weapons\u2014the Pentagon has become increasingly concerned with what it calls \u201cspace situational awareness.\u201d Instead of being a benign environment, the Pentagon likes to say that space has become \u201ccontested, congested and competitive.\u201d In orbit, debris moves very fast, as much as 17,500 m.p.h., so that even a fleck of paint could cause damage. In 2007, the Chinese fired a missile that blew up a dead satellite and littered space with thousands of pieces of debris. And the Air Force has been working to make its satellites more resilie ...

# %%
text = ' '.join(map(lambda p: p.text, soup.find_all('article')))
text
# Out:
# u"      The Space Surveillance Telescope offers improvements in determining the orbits of newly discovered objects and provides rapid observations of events that may only occur over a relatively short period of time, like a supernova. (DARPAtv)   There are a lot of rocks flying around through space. Lots of debris, too. Old satellites, spent rocket boosters, even for a short while a spatula that got loose during a space shuttle mission in 2006. All of it swirling around in orbit, creating a bit of a traffic jam. For years, the Pentagon has been worried about the collisions that might be caused by an\xa0estimated 500,000 pieces of debris, taking out enormously valuable satellites and, in turn, creating even more debris. On Tuesday, the Defense Department\xa0took another significant step toward monitoring all of the cosmic junk swirling around in space, by delivering\xa0a gigantic new telescope capable of seeing small objects from very far away. Developed by the Defense Advanced Research Project Agency, the Space Surveillance Telescope was formally transferred to the Air Force during a ceremony at White Sands Missile Base in New Mexico Tuesday. The telescope is designed to monitor objects as small as softballs, in Geosynchonous orbit (GEO)\u2014some of the most important real estate in space. At about 22,000 miles away, its orbit mirrors that of the Earth, so that satellites parked there remain in a fixed point over the globe. That allows satellite television or communications providers to serve particular areas\u2014say, North America or Asia\u2014uninterrupted. But not only is the orbit far away\u2014it\u2019s incredibly vast. \u201cA volume of tens of thousands of oceans,\u201d said Lindsay Millard, DARPA\u2019s program manager in a podcast posted on the agency\u2019s website. But the telescope's ability to see \u201csomething very far away over a very wide area is really what it\u2019s best at.\u201d DARPA says the advanced technology in the massive, 90-ton telescope would\xa0allow officials to go from \u201cseeing only a few large objects at a time through the equivalent of a drinking straw to a windshield view with 10,000 objects at a time.\u201d\xa0It is also being used by NASA to monitor asteroids and other near-Earth objects that could collide with the planet, officials said. Over the next two years, the telescope is going to be moved and reconstructed in Australia, a vantage point that would allow it to survey an under served area of space. The telescope is \u201ca big improvement over the legacy ground-based optical telescopes that are used by the U.S. Air Force, because it can search large areas of sky and also track very faint (small) objects in and around GEO,\u201d Brian Weeden, a Technical Advisor at the Secure World Foundation, wrote in an email. \u201cThat's a critical capability for the U.S. military, as they have a lot of very important satellites in GEO, and are increasingly worried about threats to those satellites.\u201d The telescope would\xa0join another new space debris tracking technology known as the Space Fence, which is now being built by Bethesda-based Lockheed Martin. The radar system is going to be located on Kwajalein Atoll in the Marshall Islands and would use radar to help the Air Force track 10 times amount of debris than it currently monitors. With many valuable assets in space\u2014satellites used for intelligence, communications and guiding weapons\u2014the Pentagon has become increasingly concerned with what it calls \u201cspace situational awareness.\u201d Instead of being a benign environment, the Pentagon likes to say that space has become \u201ccontested, congested and competitive.\u201d In orbit, debris moves very fast, as much as 17,500 m.p.h., so that even a fleck of paint could cause damage. In 2007, the Chinese fired a missile that blew up a dead satellite and littered space with thousands of pieces of debris. And the Air Force has been working to make its satellites more resilie ...

# %%
text.encode('ascii', errors='replace').replace("?"," ")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-f893defcc0af> in <module>()
# ----> 1 text.encode('ascii', errors='replace').replace("?"," ")
#
# NameError: name 'text' is not defined

# %%
def getTextWaPo(url) :
    page = urllib2.urlopen(url).read().decode('utf8', 'ignore')
    soup = BeautifulSoup(page,"lxml")
    text = ' '.join(map(lambda p: p.text, soup.find_all('article')))
    return text.encode('ascii', errors='replace').replace("?"," ")

# %%
text  = getTextWaPo(articleURL)

# %%
from nltk.tokenize import sent_tokenize,word_tokenize
from nltk.corpus import stopwords
from string import punctuation
sents = sent_tokenize(text)
sents
# Out:
# [u'      The Space Surveillance Telescope offers improvements in determining the orbits of newly discovered objects and provides rapid observations of events that may only occur over a relatively short period of time, like a supernova.',
#  u'(DARPAtv)   There are a lot of rocks flying around through space.',
#  u'Lots of debris, too.',
#  u'Old satellites, spent rocket boosters, even for a short while a spatula that got loose during a space shuttle mission in 2006.',
#  u'All of it swirling around in orbit, creating a bit of a traffic jam.',
#  u'For years, the Pentagon has been worried about the collisions that might be caused by an\xa0estimated 500,000 pieces of debris, taking out enormously valuable satellites and, in turn, creating even more debris.',
#  u'On Tuesday, the Defense Department\xa0took another significant step toward monitoring all of the cosmic junk swirling around in space, by delivering\xa0a gigantic new telescope capable of seeing small objects from very far away.',
#  u'Developed by the Defense Advanced Research Project Agency, the Space Surveillance Telescope was formally transferred to the Air Force during a ceremony at White Sands Missile Base in New Mexico Tuesday.',
#  u'The telescope is designed to monitor objects as small as softballs, in Geosynchonous orbit (GEO)\u2014some of the most important real estate in space.',
#  u'At about 22,000 miles away, its orbit mirrors that of the Earth, so that satellites parked there remain in a fixed point over the globe.',
#  u'That allows satellite television or communications providers to serve particular areas\u2014say, North America or Asia\u2014uninterrupted.',
#  u'But not only is the orbit far away\u2014it\u2019s incredibly vast.',
#  u'\u201cA volume of tens of thousands of oceans,\u201d said Lindsay Millard, DARPA\u2019s program manager in a podcast posted on the agency\u2019s website.',
#  u"But the telescope's ability to see \u201csomething very far away over a very wide area is really what it\u2019s best at.\u201d DARPA says the advanced technology in the massive, 90-ton telescope would\xa0allow officials to go from \u201cseeing only a few large objects at a time through the equivalent of a drinking straw to a windshield view with 10,000 objects at a time.\u201d\xa0It is also being used by NASA to monitor asteroids and other near-Earth objects that could collide with the planet, officials said.",
#  u'Over the next two years, the telescope is going to be moved and reconstructed in Australia, a vantage point that would allow it to survey an under served area of space.',
#  u'The telescope is \u201ca big improvement over the legacy ground-based optical telescopes that are used by the U.S. Air Force, because it can search large areas of sky and also track very faint (small) objects in and around GEO,\u201d Brian Weeden, a Technical Advisor at the Secure World Foundation, wrote in an email.',
#  u"\u201cThat's a critical capability for the U.S. military, as they have a lot of very important satellites in GEO, and are increasingly worried about threats to those satellites.\u201d The telescope would\xa0join another new space debris tracking technology known as the Space Fence, which is now being built by Bethesda-based Lockheed Martin.",
#  u'The radar system is going to be located on Kwajalein Atoll in the Marshall Islands and would use radar to help the Air Force track 10 times amount of debris than it currently monitors.',
#  u'With many valuable assets in space\u2014satellites used for intelligence, communications and guiding weapons\u2014the Pentagon has become increasingly concerned with what it calls \u201cspace situational awareness.\u201d Instead of being a benign environment, the Pentagon likes to say that space has become \u201ccontested, congested and competitive.\u201d In orbit, debris moves very fast, as much as 17,500 m.p.h., so that even a fleck of paint could cause damage.',
#  u'In 2007, the Chinese fired a missile that blew up a dead satellite and littered space with thousands of pieces of debris.',
#  u'And the Air Force has been working to make its satellites more resilient.',
#  u'It has plans to send swarms of small satellites into orbit that are more difficult to target.',
#  u'\u201cEvery military operation that takes place in the world today is critically dependent on space in one way or another,\u201d Air Force Gen. John Hyten said in an interview earlier this year when he was the commander of the Air Force Space Command.',
#  u'\u201cWhether our own people in the United States are fully cognizant of the dependence on space or not, the rest of the world has been watching us very closely.\u201d']

# %%
word_sent = word_tokenize(text.lower())
word_sent
# Out:
# [u'the',
#  u'space',
#  u'surveillance',
#  u'telescope',
#  u'offers',
#  u'improvements',
#  u'in',
#  u'determining',
#  u'the',
#  u'orbits',
#  u'of',
#  u'newly',
#  u'discovered',
#  u'objects',
#  u'and',
#  u'provides',
#  u'rapid',
#  u'observations',
#  u'of',
#  u'events',
#  u'that',
#  u'may',
#  u'only',
#  u'occur',
#  u'over',
#  u'a',
#  u'relatively',
#  u'short',
#  u'period',
#  u'of',
#  u'time',
#  u',',
#  u'like',
#  u'a',
#  u'supernova',
#  u'.',
#  u'(',
#  u'darpatv',
#  u')',
#  u'there',
#  u'are',
#  u'a',
#  u'lot',
#  u'of',
#  u'rocks',
#  u'flying',
#  u'around',
#  u'through',
#  u'space',
#  u'.',
#  u'lots',
#  u'of',
#  u'debris',
#  u',',
#  u'too',
#  u'.',
#  u'old',
#  u'satellites',
#  u',',
#  u'spent',
#  u'rocket',
#  u'boosters',
#  u',',
#  u'even',
#  u'for',
#  u'a',
#  u'short',
#  u'while',
#  u'a',
#  u'spatula',
#  u'that',
#  u'got',
#  u'loose',
#  u'during',
#  u'a',
#  u'space',
#  u'shuttle',
#  u'mission',
#  u'in',
#  u'2006.',
#  u'all',
#  u'of',
#  u'it',
#  u'swirling',
#  u'around',
#  u'in',
#  u'orbit',
#  u',',
#  u'creating',
#  u'a',
#  u'bit',
#  u'of',
#  u'a',
#  u'traffic',
#  u'jam',
#  u'.',
#  u'for',
#  u'years',
#  u',',
#  u'the',
#  u'pentagon',
#  u'has',
#  u'been',
#  u'worried',
#  u'about',
#  u'the',
#  u'collisions',
#  u'that',
#  u'might',
#  u'be',
#  u'caused',
#  u'by',
#  u'an',
#  u'estimated',
#  u'500,000',
#  u'pieces',
#  u'of',
#  u'debris',
#  u',',
#  u'taking',
#  u'out',
#  u'enormously',
#  u'valuable',
#  u'satellites',
#  u'and',
#  u',',
#  u'in',
#  u'turn',
#  u',',
#  u'creating',
#  u'even',
#  u'more',
#  u'debris',
#  u'.',
#  u'on',
#  u'tuesday',
#  u',',
#  u'the',
#  u'defense',
#  u'department',
#  u'took',
#  u'another',
#  u'significant',
#  u'step',
#  u'toward',
#  u'monitoring',
#  u'all',
#  u'of',
#  u'the',
#  u'cosmic',
#  u'junk',
#  u'swirling',
#  u'around',
#  u'in',
#  u'space',
#  u',',
#  u'by',
#  u'delivering',
#  u'a',
#  u'gigantic',
#  u'new',
#  u'telescope',
#  u'capable',
#  u'of',
#  u'seeing',
#  u'small',
#  u'objects',
#  u'from',
#  u'very',
#  u'far',
#  u'away',
#  u'.',
#  u'developed',
#  u'by',
#  u'the',
#  u'defense',
#  u'advanced',
#  u'research',
#  u'project',
#  u'agency',
#  u',',
#  u'the',
#  u'space',
#  u'surveillance',
#  u'telescope',
#  u'was',
#  u'formally',
#  u'transferred',
#  u'to',
#  u'the',
#  u'air',
#  u'force',
#  u'during',
#  u'a',
#  u'ceremony',
#  u'at',
#  u'white',
#  u'sands',
#  u'missile',
#  u'base',
#  u'in',
#  u'new',
#  u'mexico',
#  u'tuesday',
#  u'.',
#  u'the',
#  u'telescope',
#  u'is',
#  u'designed',
#  u'to',
#  u'monitor',
#  u'objects',
#  u'as',
#  u'small',
#  u'as',
#  u'softballs',
#  u',',
#  u'in',
#  u'geosynchonous',
#  u'orbit',
#  u'(',
#  u'geo',
#  u')',
#  u'\u2014some',
#  u'of',
#  u'the',
#  u'most',
#  u'important',
#  u'real',
#  u'estate',
#  u'in',
#  u'space',
#  u'.',
#  u'at',
#  u'about',
#  u'22,000',
#  u'miles',
#  u'away',
#  u',',
#  u'its',
#  u'orbit',
#  u'mirrors',
#  u'that',
#  u'of',
#  u'the',
#  u'earth',
#  u',',
#  u'so',
#  u'that',
#  u'satellites',
#  u'parked',
#  u'there',
#  u'remain',
#  u'in',
#  u'a',
#  u'fixed',
#  u'point',
#  u'over',
#  u'the',
#  u'globe',
#  u'.',
#  u'that',
#  u'allows',
#  u'satellite',
#  u'television',
#  u'or',
#  u'communications',
#  u'providers',
#  u'to',
#  u'serve',
#  u'particular',
#  u'areas\u2014say',
#  u',',
#  u'north',
#  u'america',
#  u'or',
#  u'asia\u2014uninterrupted',
#  u'.',
#  u'but',
#  u'not',
#  u'only',
#  u'is',
#  u'the',
#  u'orbit',
#  u'far',
#  u'away\u2014it',
#  u'\u2019',
#  u's',
#  u'incredibly',
#  u'vast',
#  u'.',
#  u'\u201c',
#  u'a',
#  u'volume',
#  u'of',
#  u'tens',
#  u'of',
#  u'thousands',
#  u'of',
#  u'oceans',
#  u',',
#  u'\u201d',
#  u'said',
#  u'lindsay',
#  u'millard',
#  u',',
#  u'darpa',
#  u'\u2019',
#  u's',
#  u'program',
#  u'manager',
#  u'in',
#  u'a',
#  u'podcast',
#  u'posted',
#  u'on',
#  u'the',
#  u'agency',
#  u'\u2019',
#  u's',
#  u'website',
#  u'.',
#  u'but',
#  u'the',
#  u'telescope',
#  u"'s",
#  u'ability',
#  u'to',
#  u'see',
#  u'\u201c',
#  u'something',
#  u'very',
#  u'far',
#  u'away',
#  u'over',
#  u'a',
#  u'very',
#  u'wide',
#  u'area',
#  u'is',
#  u'really',
#  u'what',
#  u'it',
#  u'\u2019',
#  u's',
#  u'best',
#  u'at.',
#  u'\u201d',
#  u'darpa',
#  u'says',
#  u'the',
#  u'advanced',
#  u'technology',
#  u'in',
#  u'the',
#  u'massive',
#  u',',
#  u'90-ton',
#  u'telescope',
#  u'would',
#  u'allow',
#  u'officials',
#  u'to',
#  u'go',
#  u'from',
#  u'\u201c',
#  u'seeing',
#  u'only',
#  u'a',
#  u'few',
#  u'large',
#  u'objects',
#  u'at',
#  u'a',
#  u'time',
#  u'through',
#  u'the',
#  u'equivalent',
#  u'of',
#  u'a',
#  u'drinking',
#  u'straw',
#  u'to',
#  u'a',
#  u'windshield',
#  u'view',
#  u'with',
#  u'10,000',
#  u'objects',
#  u'at',
#  u'a',
#  u'time.',
#  u'\u201d',
#  u'it',
#  u'is',
#  u'also',
#  u'being',
#  u'used',
#  u'by',
#  u'nasa',
#  u'to',
#  u'monitor',
#  u'asteroids',
#  u'and',
#  u'other',
#  u'near-earth',
#  u'objects',
#  u'that',
#  u'could',
#  u'collide',
#  u'with',
#  u'the',
#  u'planet',
#  u',',
#  u'officials',
#  u'said',
#  u'.',
#  u'over',
#  u'the',
#  u'next',
#  u'two',
#  u'years',
#  u',',
#  u'the',
#  u'telescope',
#  u'is',
#  u'going',
#  u'to',
#  u'be',
#  u'moved',
#  u'and',
#  u'reconstructed',
#  u'in',
#  u'australia',
#  u',',
#  u'a',
#  u'vantage',
#  u'point',
#  u'that',
#  u'would',
#  u'allow',
#  u'it',
#  u'to',
#  u'survey',
#  u'an',
#  u'under',
#  u'served',
#  u'area',
#  u'of',
#  u'space',
#  u'.',
#  u'the',
#  u'telescope',
#  u'is',
#  u'\u201c',
#  u'a',
#  u'big',
#  u'improvement',
#  u'over',
#  u'the',
#  u'legacy',
#  u'ground-based',
#  u'optical',
#  u'telescopes',
#  u'that',
#  u'are',
#  u'used',
#  u'by',
#  u'the',
#  u'u.s.',
#  u'air',
#  u'force',
#  u',',
#  u'because',
#  u'it',
#  u'can',
#  u'search',
#  u'large',
#  u'areas',
#  u'of',
#  u'sky',
#  u'and',
#  u'also',
#  u'track',
#  u'very',
#  u'faint',
#  u'(',
#  u'small',
#  u')',
#  u'objects',
#  u'in',
#  u'and',
#  u'around',
#  u'geo',
#  u',',
#  u'\u201d',
#  u'brian',
#  u'weeden',
#  u',',
#  u'a',
#  u'technical',
#  u'advisor',
#  u'at',
#  u'the',
#  u'secure',
#  u'world',
#  u'foundation',
#  u',',
#  u'wrote',
#  u'in',
#  u'an',
#  u'email',
#  u'.',
#  u'\u201c',
#  u'that',
#  u"'s",
#  u'a',
#  u'critical',
#  u'capability',
#  u'for',
#  u'the',
#  u'u.s.',
#  u'military',
#  u',',
#  u'as',
#  u'they',
#  u'have',
#  u'a',
#  u'lot',
#  u'of',
#  u'very',
#  u'important',
#  u'satellites',
#  u'in',
#  u'geo',
#  u',',
#  u'and',
#  u'are',
#  u'increasingly',
#  u'worried',
#  u'about',
#  u'threats',
#  u'to',
#  u'those',
#  u'satellites.',
#  u'\u201d',
#  u'the',
#  u'telescope',
#  u'would',
#  u'join',
#  u'another',
#  u'new',
#  u'space',
#  u'debris',
#  u'tracking',
#  u'technology',
#  u'known',
#  u'as',
#  u'the',
#  u'space',
#  u'fence',
#  u',',
#  u'which',
#  u'is',
#  u'now',
#  u'being',
#  u'built',
#  u'by',
#  u'bethesda-based',
#  u'lockheed',
#  u'martin',
#  u'.',
#  u'the',
#  u'radar',
#  u'system',
#  u'is',
#  u'going',
#  u'to',
#  u'be',
#  u'located',
#  u'on',
#  u'kwajalein',
#  u'atoll',
#  u'in',
#  u'the',
#  u'marshall',
#  u'islands',
#  u'and',
#  u'would',
#  u'use',
#  u'radar',
#  u'to',
#  u'help',
#  u'the',
#  u'air',
#  u'force',
#  u'track',
#  u'10',
#  u'times',
#  u'amount',
#  u'of',
#  u'debris',
#  u'than',
#  u'it',
#  u'currently',
#  u'monitors',
#  u'.',
#  u'with',
#  u'many',
#  u'valuable',
#  u'assets',
#  u'in',
#  u'space\u2014satellites',
#  u'used',
#  u'for',
#  u'intelligence',
#  u',',
#  u'communications',
#  u'and',
#  u'guiding',
#  u'weapons\u2014the',
#  u'pentagon',
#  u'has',
#  u'become',
#  u'increasingly',
#  u'concerned',
#  u'with',
#  u'what',
#  u'it',
#  u'calls',
#  u'\u201c',
#  u'space',
#  u'situational',
#  u'awareness.',
#  u'\u201d',
#  u'instead',
#  u'of',
#  u'being',
#  u'a',
#  u'benign',
#  u'environment',
#  u',',
#  u'the',
#  u'pentagon',
#  u'likes',
#  u'to',
#  u'say',
#  u'that',
#  u'space',
#  u'has',
#  u'become',
#  u'\u201c',
#  u'contested',
#  u',',
#  u'congested',
#  u'and',
#  u'competitive.',
#  u'\u201d',
#  u'in',
#  u'orbit',
#  u',',
#  u'debris',
#  u'moves',
#  u'very',
#  u'fast',
#  u',',
#  u'as',
#  u'much',
#  u'as',
#  u'17,500',
#  u'm.p.h.',
#  u',',
#  u'so',
#  u'that',
#  u'even',
#  u'a',
#  u'fleck',
#  u'of',
#  u'paint',
#  u'could',
#  u'cause',
#  u'damage',
#  u'.',
#  u'in',
#  u'2007',
#  u',',
#  u'the',
#  u'chinese',
#  u'fired',
#  u'a',
#  u'missile',
#  u'that',
#  u'blew',
#  u'up',
#  u'a',
#  u'dead',
#  u'satellite',
#  u'and',
#  u'littered',
#  u'space',
#  u'with',
#  u'thousands',
#  u'of',
#  u'pieces',
#  u'of',
#  u'debris',
#  u'.',
#  u'and',
#  u'the',
#  u'air',
#  u'force',
#  u'has',
#  u'been',
#  u'working',
#  u'to',
#  u'make',
#  u'its',
#  u'satellites',
#  u'more',
#  u'resilient',
#  u'.',
#  u'it',
#  u'has',
#  u'plans',
#  u'to',
#  u'send',
#  u'swarms',
#  u'of',
#  u'small',
#  u'satellites',
#  u'into',
#  u'orbit',
#  u'that',
#  u'are',
#  u'more',
#  u'difficult',
#  u'to',
#  u'target',
#  u'.',
#  u'\u201c',
#  u'every',
#  u'military',
#  u'operation',
#  u'that',
#  u'takes',
#  u'place',
#  u'in',
#  u'the',
#  u'world',
#  u'today',
#  u'is',
#  u'critically',
#  u'dependent',
#  u'on',
#  u'space',
#  u'in',
#  u'one',
#  u'way',
#  u'or',
#  u'another',
#  u',',
#  u'\u201d',
#  u'air',
#  u'force',
#  u'gen.',
#  u'john',
#  u'hyten',
#  u'said',
#  u'in',
#  u'an',
#  u'interview',
#  u'earlier',
#  u'this',
#  u'year',
#  u'when',
#  u'he',
#  u'was',
#  u'the',
#  u'commander',
#  u'of',
#  u'the',
#  u'air',
#  u'force',
#  u'space',
#  u'command',
#  u'.',
#  u'\u201c',
#  u'whether',
#  u'our',
#  u'own',
#  u'people',
#  u'in',
#  u'the',
#  u'united',
#  u'states',
#  u'are',
#  u'fully',
#  u'cognizant',
#  u'of',
#  u'the',
#  u'dependence',
#  u'on',
#  u'space',
#  u'or',
#  u'not',
#  u',',
#  u'the',
#  u'rest',
#  u'of',
#  u'the',
#  u'world',
#  u'has',
#  u'been',
#  u'watching',
#  u'us',
#  u'very',
#  u'closely',
#  u'.',
#  u'\u201d']

# %%
_stopwords = set(stopwords.words('english') + list(punctuation))
_stopwords
# Out:
# {'!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  u'a',
#  u'about',
#  u'above',
#  u'after',
#  u'again',
#  u'against',
#  u'ain',
#  u'all',
#  u'am',
#  u'an',
#  u'and',
#  u'any',
#  u'are',
#  u'aren',
#  u'as',
#  u'at',
#  u'be',
#  u'because',
#  u'been',
#  u'before',
#  u'being',
#  u'below',
#  u'between',
#  u'both',
#  u'but',
#  u'by',
#  u'can',
#  u'couldn',
#  u'd',
#  u'did',
#  u'didn',
#  u'do',
#  u'does',
#  u'doesn',
#  u'doing',
#  u'don',
#  u'down',
#  u'during',
#  u'each',
#  u'few',
#  u'for',
#  u'from',
#  u'further',
#  u'had',
#  u'hadn',
#  u'has',
#  u'hasn',
#  u'have',
#  u'haven',
#  u'having',
#  u'he',
#  u'her',
#  u'here',
#  u'hers',
#  u'herself',
#  u'him',
#  u'himself',
#  u'his',
#  u'how',
#  u'i',
#  u'if',
#  u'in',
#  u'into',
#  u'is',
#  u'isn',
#  u'it',
#  u'its',
#  u'itself',
#  u'just',
#  u'll',
#  u'm',
#  u'ma',
#  u'me',
#  u'mightn',
#  u'more',
#  u'most',
#  u'mustn',
#  u'my',
#  u'myself',
#  u'needn',
#  u'no',
#  u'nor',
#  u'not',
#  u'now',
#  u'o',
#  u'of',
#  u'off',
#  u'on',
#  u'once',
#  u'only',
#  u'or',
#  u'other',
#  u'our',
#  u'ours',
#  u'ourselves',
#  u'out',
#  u'over',
#  u'own',
#  u're',
#  u's',
#  u'same',
#  u'shan',
#  u'she',
#  u'should',
#  u'shouldn',
#  u'so',
#  u'some',
#  u'such',
#  u't',
#  u'than',
#  u'that',
#  u'the',
#  u'their',
#  u'theirs',
#  u'them',
#  u'themselves',
#  u'then',
#  u'there',
#  u'these',
#  u'they',
#  u'this',
#  u'those',
#  u'through',
#  u'to',
#  u'too',
#  u'under',
#  u'until',
#  u'up',
#  u've',
#  u'very',
#  u'was',
#  u'wasn',
#  u'we',
#  u'were',
#  u'weren',
#  u'what',
#  u'when',
#  u'where',
#  u'which',
#  u'while',
#  u'who',
#  u'whom',
#  u'why',
#  u'will',
#  u'with',
#  u'won',
#  u'wouldn',
#  u'y',
#  u'you',
#  u'your',
#  u'yours',
#  u'yourself',
#  u'yourselves',
#  '{',
#  '|',
#  '}',
#  '~'}
